# %%
import numpy as np
from Maze import Maze 
import matplotlib.pyplot as plt

# %%
'''Generate a 30x30 maze and plot it'''
M=Maze(30,30)
M.plot()

# %%
#Solve the maze
M.solve()
# Out:
# Path found in 42 steps

# %%
#Plot the maze again with the solution
M.plot(path=M.path)

# %%
# Read in a Maze
M=Maze(file='test.dat')
M.plot()
M.solve()
# Out:
# Path found in 38 steps

# %%
M.plot(path=M.path)

# %%
# We can even create a movie of the Solution
M.movie('Example.mp4')
